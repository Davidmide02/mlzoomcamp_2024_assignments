# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the dataset
df = pd.read_csv('bank-full.csv', sep=';')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
# check for the numbers of unique values in the dataset
for col in df.columns:
    uni_val = df[col].nunique()
    print(col ,uni_val)
# Out:
# age 77
# job 12
# marital 3
# education 4
# default 2
# balance 7168
# housing 2
# loan 2
# contact 3
# day 31
# month 12
# duration 1573
# campaign 48
# pdays 559
# previous 41
# poutcome 4
# y 2

# %%
# select the features
df_selected_fea = df.drop(['default', 'loan'], axis=1)

# %%
df_selected_fea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   balance    45211 non-null  int64
#  5   housing    45211 non-null  object
#  6   contact    45211 non-null  object
#  7   day        45211 non-null  int64
#  8   month      45211 non-null  object
#  9   duration   45211 non-null  int64
#  10  campaign   45211 non-null  int64
#  11  pdays      45211 non-null  int64
#  12  previous   45211 non-null  int64
#  13  poutcome   45211 non-null  object
#  14  y          45211 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 5.2+ MB

# %%
df_selected_fea['y']= df_selected_fea['y'].map({'yes':1, 'no':0})

# %%
df_selected_fea.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
education_col_mode = df_selected_fea['education'].mode()

print(f"Education mode is : {education_col_mode[0]}")
# Out:
# Education mode is : secondary

# %%
df_selected_fea.iloc[::10]
# Out:
#        age           job   marital  education  balance housing    contact  \
# 0       58    management   married   tertiary     2143     yes    unknown
# 10      41        admin.  divorced  secondary      270     yes    unknown
# 20      28   blue-collar   married  secondary      723     yes    unknown
# 30      57    technician   married  secondary      839      no    unknown
# 40      44      services  divorced  secondary     2586     yes    unknown
# ...    ...           ...       ...        ...      ...     ...        ...
# 45170   19       student    single    primary      245      no  telephone
# 45180   66       retired   married  secondary     3409      no   cellular
# 45190   32   blue-collar   married  secondary      136      no   cellular
# 45200   38    technician   married  secondary      557     yes   cellular
# 45210   37  entrepreneur   married  secondary     2971      no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# 0        5   may       261         1     -1         0  unknown   no
# 10       5   may       222         1     -1         0  unknown   no
# 20       5   may       262         1     -1         0  unknown   no
# 30       5   may       225         1     -1         0  unknown   no
# 40       5   may       160         1     -1         0  unknown   no
# ...    ...   ...       ...       ...    ...       ...      ...  ...
# 45170   10   nov        98         2    110         2    other   no
# 45180   15   nov       414         2     27         6  failure   no
# 45190   16   nov       206         1    188         3  success  yes
# 45200   16   nov      1556         4     -1         0  unknown  yes
# 45210   17   nov       361         2    188        11    other   no
#
# [4522 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
df_full_train, df_test = train_test_split(df_selected_fea,test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)
len(df_selected_fea), len(df_train), len(df_test), len(df_val)
# Out:
# (45211, 27126, 9043, 9042)

# %%
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_train =df_train.reset_index(drop=True)
df_val
# Out:
#       age          job  marital  education  balance housing    contact  day  \
# 0      57  blue-collar  married    primary      856      no   cellular   11
# 1      50    housemaid  married    primary        0      no   cellular   27
# 2      30   management   single   tertiary     5956     yes    unknown    8
# 3      33  blue-collar  married  secondary      312     yes    unknown    4
# 4      54   technician   single  secondary      198     yes   cellular   17
# ...   ...          ...      ...        ...      ...     ...        ...  ...
# 9037   54   technician  married  secondary     -939     yes    unknown   29
# 9038   37   management  married   tertiary     8821     yes   cellular   14
# 9039   62      unknown  married  secondary      367      no  telephone    7
# 9040   44  blue-collar  married    primary     1432     yes    unknown   27
# 9041   35   technician  married  secondary      222     yes   cellular   18
#
#      month  duration  campaign  pdays  previous poutcome   y
# 0      aug       194         6     -1         0  unknown  no
# 1      aug        52         3     -1         0  unknown  no
# 2      may       255         1     -1         0  unknown  no
# 3      jun       151         2     -1         0  unknown  no
# 4      nov       120         1    171         2  failure  no
# ...    ...       ...       ...    ...       ...      ...  ..
# 9037   may       202         1     -1         0  unknown  no
# 9038   may       167         1     -1         0  unknown  no
# 9039   sep       221         1    189         5  failure  no
# 9040   may        63         9     -1         0  unknown  no
# 9041   nov       233         1    190         6  failure  no
#
# [9042 rows x 15 columns]

# %%
y_train = df_train['y']
y_test = df_test['y']
y_train = df_train['y']

# %%
del df_train['y']
del df_val['y']
del df_test['y']

# %% [markdown]
# ### EDA
# - check missing values
# - look at the target variable (y)
# - Look at the numerical and categorical variables

# %%
df_full_train = df_full_train.reset_index(drop=True)
df_full_train.head()
# Out:
#    age          job  marital  education  balance housing   contact  day month  \
# 0   52   management  married   tertiary        0      no  cellular   22   aug
# 1   50       admin.   single  secondary      330     yes   unknown   28   may
# 2   45  blue-collar  married    primary      300     yes  cellular   29   jan
# 3   38   technician  married  secondary       27     yes   unknown    3   jun
# 4   31     services   single  secondary      887      no  cellular   30   jan
#
#    duration  campaign  pdays  previous poutcome   y
# 0       232         2     -1         0  unknown  no
# 1        24         1     -1         0  unknown  no
# 2       203         1    261         3  failure  no
# 3       404         4     -1         0  unknown  no
# 4       427         1     -1         0  unknown  no

# %%
df_full_train.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df_full_train.y.value_counts(normalize=True)
# Out:
# y
# no     0.882797
# yes    0.117203
# Name: proportion, dtype: float64

# %%
df_full_train['y']= df_full_train['y'].map({'yes':1, 'no':0})

# %%
df_full_train['y'].iloc[::10]
# Out:
# 0        0
# 10       0
# 20       0
# 30       0
# 40       0
#         ..
# 36120    0
# 36130    0
# 36140    0
# 36150    0
# 36160    0
# Name: y, Length: 3617, dtype: int64

# %%
globsl_churn_rate = df_full_train.mean()
globsl_churn_rate
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 globsl_churn_rate = df_full_train.mean()
#       2 globsl_churn_rate
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\internals\managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\internals\blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File c:\Users\David\OneDrive\Desktop\mlzoomcamp_2024\mlvenv\Lib\site-packages\pandas\core\nanops.py:1686, in _ensure_numeric(x)
#    1683 inferred = lib.infer_dtype(x)
#    1684 if inferred in ["string", "mixed"]:
#    1685     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1686     raise TypeError(f"Could not convert {x} to numeric")
#    1687 try:
#    1688     x = x.astype(np.complex128)
#
# TypeError: Could not convert ['managementadmin.blue-collartechnicianservicesadmin.technicianunknownmanagementmanagementretiredadmin.servicesservicesretiredmanagementtechnicianblue-collaradmin.admin.admin.studententrepreneurunemployedmanagementblue-collarblue-collarretiredblue-collarservicesmanagementblue-collartechnicianadmin.retiredhousemaidmanagementblue-collarservicesservicestechniciantechnicianblue-collarentrepreneurstudentmanagementmanagementtechnicianself-employedblue-collartechnicianblue-collartechnicianblue-collarblue-collarservicesretiredservicestechnicianretiredblue-collaradmin.blue-collartechnicianmanagementservicesblue-collarmanagementtechniciantechnicianmanagementtechnicianblue-collarstudentmanagementtechnicianblue-collarservicesservicesretiredadmin.managementservicestechnicianstudententrepreneurretiredblue-collarmanagementtechnicianadmin.blue-collarmanagementmanagementadmin.retiredretiredadmin.managementservicesblue-collarself-employedtechnicianmanagementadmin.blue-collarmanagementservic
# education    tertiary  secondary      primary   secondary  secondary
# balance             0        330          300          27        887
# housing            no        yes          yes         yes         no
# contact      cellular    unknown     cellular     unknown   cellular
# day                22         28           29           3         30
# month             aug        may          jan         jun        jan
# duration          232         24          203         404        427
# campaign            2          1            1           4          1
# pdays              -1         -1          261          -1         -1
# previous            0          0            3           0          0
# poutcome      unknown    unknown      failure     unknown    unknown
# y                   0          0            0           0          0
#
#               5           6        7           8           9      ...  \
# age              41          23       47          30          33  ...
# job          admin.  technician  unknown  management  management  ...
# marital     married     married  married     married      single  ...
# education  tertiary   secondary  unknown    tertiary   secondary  ...
# balance         226           4     1880         604           0  ...
# housing         yes         yes       no          no         yes  ...
# contact    cellular    cellular  unknown    cellular     unknown  ...
# day              15          20       18          25          26  ...
# month           jul         apr      jun         aug         may  ...
# duration        157         698       64         132         816  ...
# campaign          5           1        2           2           2  ...
# pdays            -1          -1       -1          -1          -1  ...
# previous          0           0        0           0           0  ...
# poutcome    unknown     unknown  unknown     unknown     unknown  ...
# y                 0           0        0           0           0  ...
#
#                  36158       36159      36160       36161       36162  \
# age                 36          30         29          33          36
# job        blue-collar  management     admin.  technician  management
# marital        married      single     single      single      single
# education    secondary    tertiary  secondary   secondary    tertiary
# balance            740          67       3432       12177        2806
# housing            yes          no        yes          no         yes
# contact        unknown    cellular   cellular    cellular     unknown
# day                 30          12         17          18          30
# month              may         aug        apr         aug         may
# duration           171         578        139          76         358
# campaign             2           4          2           5           4
# pdays               -1          -1         -1          -1          -1
# previous             0           0          0           0           0
# poutcome       unknown     unknown    unknown     unknown     unknown
# y                    0           0          0           0           0
#
#                 36163       36164       36165    36166        36167
# age                50          34          48       45           45
# job        technician  management  management   admin.  blue-collar
# marital       married    divorced     married  married      married
# education    tertiary    tertiary    tertiary  unknown      unknown
# balance          1830         528        4191     1783          349
# housing            no         yes          no       no          yes
# contact      cellular    cellular     unknown  unknown     cellular
# day                14          17          21       20           17
# month             may         apr         may      jun          apr
# duration          318         233         363       11          179
# campaign            3           2           6       11            2
# pdays              -1          -1          -1       -1          336
# previous            0           0           0        0            2
# poutcome      unknown     unknown     unknown  unknown        other
# y                   0           0           0        0            0
#
# [15 rows x 36168 columns]

# %%
# numerical feature

numerical = df_full_train.select_dtypes(include=np.number)
numerical = numerical.head(2).drop(['y'], axis=1)
numerical
# Out:
#    age  balance  day  duration  campaign  pdays  previous
# 0   52        0   22       232         2     -1         0
# 1   50      330   28        24         1     -1         0

# %%
numerical.columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
categorical = df_full_train.drop(numerical.columns, axis=1)
categorical = categorical.drop(['y'],axis=1)

# %%
categorical.head()
# Out:
#            job  marital  education housing   contact month poutcome
# 0   management  married   tertiary      no  cellular   aug  unknown
# 1       admin.   single  secondary     yes   unknown   may  unknown
# 2  blue-collar  married    primary     yes  cellular   jan  failure
# 3   technician  married  secondary     yes   unknown   jun  unknown
# 4     services   single  secondary      no  cellular   jan  unknown
